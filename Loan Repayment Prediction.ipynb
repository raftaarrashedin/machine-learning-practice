# %% [markdown]
# **Project :- Loan Repayment Prediction**

# %% [markdown]
# I need to find out if my customers are going to return the loan they took from my bank or not.
#
# Problem Statement :- To predict if A customer will repay loan amount or not using decision tree algorithm in python.

# %% [markdown]
# ----------------------------------
# Import the necessary packages

# %%
# Import the necessary packages
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
#dataset from simplilearn
balance_data = pd.read_csv('Loan Repayment.csv')
balance_data.head()
# Out:
#    Initial Payment  Last Payment  Credit Score  House Number    sum Result
# 0              201         10018           250          3046  13515    yes
# 1              205         10016           395          3044  13660    yes
# 2              257         10129           109          3251  13746    yes
# 3              246         10064           324          3137  13771    yes
# 4              117         10115           496          3094  13822    yes

# %%
print("Dataset Length :", len(balance_data))
print('Dataset Shape : ', balance_data.shape)
# Out:
# Dataset Length : 1000
# Dataset Shape :  (1000, 6)

# %%
# Separating the target variable
X = balance_data.drop('Result', axis = 'columns')
Y = balance_data.Result

# %%
# Splitting the dataset into Train and Test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 40)

# %%
# Fuction to perform training with Entropy 
clf_entropy = DecisionTreeClassifier(criterion= "entropy", random_state = 40,max_depth = 3, min_samples_leaf = 5)
clf_entropy.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=40)

# %%
# Functions to make predictions
y_pred_en = clf_entropy.predict(X_test)
print(y_pred_en)
print("\n Total answers : ", len(y_pred_en))
# Out:
# ['yes' 'yes' 'No' 'No' 'yes' 'yes' 'yes' 'yes' 'yes' 'No' 'yes' 'No' 'yes'
#  'No' 'yes' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'No' 'yes' 'No' 'No'
#  'yes' 'yes' 'yes' 'yes' 'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'No' 'No'
#  'yes' 'yes' 'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'No' 'No'
#  'No' 'yes' 'yes' 'No' 'yes' 'yes' 'No' 'No' 'yes' 'No' 'No' 'No' 'No'
#  'yes' 'yes' 'yes' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'yes' 'No' 'yes'
#  'No' 'No' 'No' 'yes' 'No' 'No' 'yes' 'yes' 'No' 'No' 'yes' 'yes' 'No'
#  'yes' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'No' 'No' 'No' 'yes' 'yes'
#  'No' 'yes' 'No' 'No' 'No' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'yes' 'No'
#  'No' 'No' 'yes' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'No'
#  'yes' 'yes' 'No' 'No' 'No' 'yes' 'yes' 'No' 'No' 'No' 'No' 'No' 'yes'
#  'No' 'yes' 'yes' 'No' 'No' 'yes' 'No' 'No' 'yes' 'yes' 'No' 'yes' 'No'
#  'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'No' 'yes' 'No' 'No'
#  'yes' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'yes' 'No' 'yes' 'No'
#  'yes' 'No' 'No' 'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'No' 'No'
#  'No' 'No' 'No' 'No']
#
#  Total answers :  200

# %%
# Checking Accuracy
print("Accuracy is : ", accuracy_score(Y_test, y_pred_en))
# Out:
# Accuracy is :  1.0
