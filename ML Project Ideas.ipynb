# %% [markdown]
# 1 :  Smart cctv
# github -
# https://github.com/Pawandeep-prog/smart-cctv-tkinter
#
# video explaination -
# https://youtu.be/vNeaJacy99s
#
# 2 :  Emotion Detection
# github -
# https://github.com/Pawandeep-prog/facial-emotion-detection-webapp
#
# video explaination -
#  https://youtu.be/q2hdXLPN8JQ
#
# 3 :  SMART VLC
# github:
# https://github.com/Pawandeep-prog/hand-gestured-vlc
#
# video:
# https://youtu.be/-Lou0eHCMf8
#
# 4 : Chatbot using keras
# github :
# https://github.com/Pawandeep-prog/chatbot
#
# videos :
# https://www.youtube.com/playlist?list=PLTuKYqpidPXbulRHl8HL7JLRQXwDlqpLO
#
# 5 : Virtual Drawing
# github:
#  https://github.com/Pawandeep-prog/draw-in-air-ver-2.0
#
# video explaination:
# https://youtu.be/BDyhyQ1qjBY
#
# ============================

# %% [markdown]
# MURTAZA ROBOTICS and AI
#
# https://www.youtube.com/channel/UCYUjYU5FveRAscQ8V21w81A

# %% [markdown]
# name some machine learning project for college project where I can learn a lot by doing that project?
# !
#
#     Predicting House Prices: Build a machine learning model that predicts the price of a house based on various factors such as location, size, number of bedrooms, etc.
#
#     Sentiment Analysis: Build a sentiment analysis model that can classify a given text as positive, negative, or neutral. This can be useful for analyzing customer feedback, social media sentiment, and more.
#
#     Image Classification: Build a machine learning model that can classify images into different categories. This can be useful for tasks such as identifying objects in photos, detecting diseases in medical images, and more.
#
#     Spam Detection: Build a machine learning model that can classify emails as spam or not spam. This can be useful for filtering unwanted messages in email inboxes.
#
#     Stock Price Prediction: Build a machine learning model that predicts the future stock prices of a company based on historical data. This can be useful for investors and traders looking to make informed decisions.
#
#     Handwriting Recognition: Build a machine learning model that can recognize handwritten text and convert it to digital text. This can be useful for tasks such as digitizing handwritten notes and forms.
#
#     Fraud Detection: Build a machine learning model that can detect fraudulent transactions in financial data. This can be useful for banks and other financial institutions to prevent fraud.
#
#     Customer Churn Prediction: Build a machine learning model that predicts the likelihood of a customer leaving a business based on their past behavior. This can be useful for businesses to identify customers who are at risk of leaving and take actions to retain them.
#
#     Language Translation: Build a machine learning model that can translate text from one language to another. This can be useful for tasks such as translating documents and websites for global audiences.
#
#     Autonomous Driving: Build a machine learning model that can control a self-driving car based on real-time data from sensors and cameras. This can be a challenging bu

# %% [markdown]
# Sentiment Analysis
#
#
# Hate Speech Detection
#
#
# Object Detection
#
#
# Movie Recommendation System
