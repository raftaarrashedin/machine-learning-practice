# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4) (2.4.1)

# %%
pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (4.9.2)

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests) (2022.12.7)

# %%
import time

# %%
from bs4 import BeautifulSoup

import requests
import time
def find_jobs() :
  html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Machine+Learning&txtLocation=Hyderabad%2F+Secunderabad&cboWorkExp1=0').text

  #print(html_text)

  soup = BeautifulSoup(html_text,'lxml')

  jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

  print('Put some skill that you are not familiar with.')

  unfamiliar_skill = input('>')

  print(f'Filtering out {unfamiliar_skill}')


  for index,job in enumerate(jobs) :



    published_date = job.find('span', class_ = 'sim-posted').span.text

    if 'few' in published_date :

      company_name = job.find('h3', class_='joblist-comp-name').text.replace('  ','')

      skills = job.find('span', class_ = 'srp-skills').text.replace('  ','')

      more_info = job.header.h2.a['href']

      if unfamiliar_skill not in skills :

        with open(f'posts/{index}.txt','w') as f :
          # print(f'''
          #   Company Name : {company_name}
          #   Required Skills : {skills}
          #   Job Status : {published_date}
          # ''')
          print('-----------------------------------')
          f.write(f"Company Name : {company_name.strip()}")
          f.write(f"Required Skills : {skills.strip()}")
          f.write(f"Published Date : {published_date.strip()}")
          f.write(f"More Info : {more_info.strip()}")
          print('-----------------------------------')

        print(f'File Saved: {index}')


if __name__ == '__main__' :
  while True:
    find_jobs()
    time_wait = 10
    print(f'Waiting {time_wait} minute...')
    time.sleep(time_wait * 60)
# Out:
# Put some skill that you are not familiar with.
# >hadoop
# Filtering out hadoop
# -----------------------------------
# Company Name : Merilytics
# Required Skills : python,bi,jee,machine learning,sql,written communication
# Published Date : Posted few days ago
# More Info : https://www.timesjobs.com/job-detail/business-analyst-merilytics-hyderabad-secunderabad-0-to-3-yrs-jobid-c1G49xkc7fRzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------
# -----------------------------------
# Company Name : MERITUS INTELYTICS PRIVATE LIMITED
# Required Skills : python,bi,jee,machine learning,sql,written communication
# Published Date : Posted few days ago
# More Info : https://www.timesjobs.com/job-detail/business-analyst-meritus-intelytics-private-limited-hyderabad-secunderabad-0-to-3-yrs-jobid-hDeDk8qJPXJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------
# -----------------------------------
# Company Name : HyreFox Consultants
# Required Skills : algorithms,python,natural language processing,machine learning,technical skills
# Published Date : Posted few days ago
# More Info : https://www.timesjobs.com/job-detail/data-science-executive-hyrefox-consultants-hyderabad-secunderabad-jaipur-bengaluru-bangalore-0-to-3-yrs-jobid-rPFYPkfd8CRzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------
# -----------------------------------
# Company Name : Teradata Corporations
# Required Skills : fundamentals,algorithms,c,software design,sql,database,system development,software engineer,data structures,big data,c,os,machine learning
# Published Date : Posted few days ago
# More Info : https://www.timesjobs.com/job-detail/sr-software-engineer-teradata-corporations-hyderabad-secunderabad-0-to-3-yrs-jobid-B5x__SLASH__Ho9RuY9zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------
# Waiting 10 minutes...
