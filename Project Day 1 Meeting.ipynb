# %% [markdown]
# Basics of ML
# - Know about all algorithms of ML
#
# Learn Basic Python Libraries
# - Numpy
# - Matplot Lib
# - Seaborn
# - Pandas

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Find idea or any problem to solve

# %% [markdown]
# Making Synopsis
